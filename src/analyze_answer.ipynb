# %%
import pandas as pd
import os
import pyarrow
import openpyxl

# %%
x2 = pd.read_parquet(os.path.join('..', 'доп. инфо', 'sample_submission', 'sample_submission_2.parquet'), engine='pyarrow')
x3 = pd.read_parquet(os.path.join('..', 'доп. инфо', 'sample_submission', 'sample_submission_3.parquet'), engine='pyarrow')

# %%
x2
# Out:
#                       DT  \
# 0    2022-01-01 00:00:00
# 1    2022-01-01 00:00:10
# 2    2022-01-01 00:00:20
# 3    2022-01-01 00:00:30
# 4    2022-01-01 00:00:40
# ...                  ...
# 4995 2022-01-01 13:52:30
# 4996 2022-01-01 13:52:40
# 4997 2022-01-01 13:52:50
# 4998 2022-01-01 13:53:00
# 4999 2022-01-01 13:53:10
#
#       Y_ЭКСГАУСТЕР А/М №9_ЗАПОРНАЯ АРМАТУРА ЭКСГАУСТЕРА №9  \
# 0                                                     0
# 1                                                     0
# 2                                                     0
# 3                                                     0
# 4                                                     0
# ...                                                 ...
# 4995                                                  0
# 4996                                                  0
# 4997                                                  0
# 4998                                                  0
# ...

# %%
x3
# Out:
#                      Y_ЭКСГАУСТЕР А/М №9_ЗАПОРНАЯ АРМАТУРА ЭКСГАУСТЕРА №9  \
# DT
# 2022-01-13 00:00:00                                            2592000
# 2022-01-13 00:00:10                                            2592000
# 2022-01-13 00:00:20                                            2592000
# 2022-01-13 00:00:30                                            2592000
# 2022-01-13 00:00:40                                            2592000
# ...                                                                ...
# 2022-02-12 16:59:20                                            2592000
# 2022-02-12 16:59:30                                            2592000
# 2022-02-12 16:59:40                                            2592000
# 2022-02-12 16:59:50                                            2592000
# 2022-02-12 17:00:00                                            2592000
#
#                      Y_ЭКСГАУСТЕР А/М №9_МАСЛОСТАНЦИЯ ЖИДКОЙ СМАЗКИ ЭКСГ. №9  \
# DT
# ...
